# %% [markdown]
# ## Reminder
# 把所有annotations放到 ./c2c 資料夾下

# %%
import pandas as pd
import os

# 定義資料夾路徑
pair_folder = './c2c'
data_csv = 'data.csv'
output_folder = './output'

# 讀取 data.csv
print("Reading data.csv...")
data_df = pd.read_csv(data_csv)

# 確保輸出資料夾存在
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# 取得所有搜尋詞
search_terms = data_df['搜尋詞'].unique()

# 逐一處理 ./c2c 資料夾中的所有 pair.csv
for search_term in search_terms:
    # 針對當前的搜尋詞，篩選出對應的 data
    search_data = data_df[data_df['搜尋詞'] == search_term].reset_index(drop=True)
    
    # 取得 A 商品與 B 商品數量
    unique_A = search_data['商品名稱A']
    unique_B = search_data['商品名稱B']
    num_A = len(unique_A)
    num_B = len(unique_B)
    
    # 生成 A*B 大小的 search_data
    search_data_expanded = pd.DataFrame(
        [(a, b) for a in unique_A for b in unique_B],
        columns=['商品名稱A', '商品名稱B']
    )
    
    # 合併其他原始欄位
    search_data_expanded = search_data_expanded.merge(
        search_data.drop_duplicates(subset=['商品名稱A'])[['商品名稱A', '商品網址A', '價格A']],
        on='商品名稱A', how='left'
    ).merge(
        search_data.drop_duplicates(subset=['商品名稱B'])[['商品名稱B', '商品網址B', '價格B']],
        on='商品名稱B', how='left'
    )
    search_data_expanded['搜尋詞'] = search_term

    # 取得 pair.csv 的檔案名稱
    pair_csv_path = os.path.join(pair_folder, f'{search_term}_annotations.csv')
    if not os.path.exists(pair_csv_path):
        print(f"Pair CSV not found for search term '{search_term}', skipping...")
        continue
    
    # 讀取 pair.csv
    print(f"Processing {pair_csv_path}...")
    pair_df = pd.read_csv(pair_csv_path, index_col=0)
    
    # 修正: 如果 pair_df 的維度與 num_A, num_B 不匹配，裁剪或擴展 pair_df 以符合
    if pair_df.shape != (num_A, num_B):
        print(f"Warning: Dimension mismatch for search term '{search_term}', expected ({num_A}, {num_B}) but got {pair_df.shape}")
        # 調整 pair_df 的大小以符合 num_A x num_B
        pair_df = pair_df.iloc[:num_A, :num_B]
        pair_df = pair_df.reindex(index=range(num_A), columns=range(num_B), fill_value='x')

    # 展開 pair_df 矩陣成為一維的列表
    labels = pair_df.values.flatten()
    
    # 將標籤結果加到原始的 search_data_expanded 中
    search_data_expanded['label'] = labels
    
    # 儲存結果到新的 CSV
    output_csv_path = os.path.join(output_folder, f'{search_term}_labeled.csv')
    search_data_expanded.to_csv(output_csv_path, index=False)
    print(f"Output saved to {output_csv_path}")

print("Processing completed.")
# Out:
# Reading data.csv...
# Processing ./c2c\LED燈泡_annotations.csv...
# Output saved to ./output\LED燈泡_labeled.csv
# Processing ./c2c\USB_annotations.csv...
# Output saved to ./output\USB_labeled.csv
# Processing ./c2c\便當盒_annotations.csv...
# Output saved to ./output\便當盒_labeled.csv
# Processing ./c2c\充電座_annotations.csv...
# Output saved to ./output\充電座_labeled.csv
# Processing ./c2c\充電線_annotations.csv...
# Output saved to ./output\充電線_labeled.csv
# Processing ./c2c\印章_annotations.csv...
# Output saved to ./output\印章_labeled.csv
# Processing ./c2c\地機器人_annotations.csv...
# Output saved to ./output\地機器人_labeled.csv
# Processing ./c2c\安全帽_annotations.csv...
# Output saved to ./output\安全帽_labeled.csv
# Processing ./c2c\帳篷_annotations.csv...
# Output saved to ./output\帳篷_labeled.csv
# Processing ./c2c\平底鍋_annotations.csv...
# Output saved to ./output\平底鍋_labeled.csv
# Pair CSV not found for search term '廚具', skipping...
# Pair CSV not found for search term '影印紙', skipping...
# Pair CSV not found for search term '悶鍋', skipping...
# Pair CSV not found for search term '手機配件', skipping...
# Pair CSV not found for search term '拉鍊', skipping...
# Pair CSV not found for search term '插頭', skipping...
# Pair CSV not found for search term '數據線', skipping...
# Pair CSV not found for search term '數鈔機', skipping...
# Pair CSV not found for search term '旅遊書', skipping...
# Pair CSV not found for search term '毛筆', skipping...
# Pair CSV not found for search term '牛仔褲', skipping...
# Pair CSV not found for search term '男裝', skipping...
# Pair CSV not found for search term '皮鞋', skipping...
# Pair CSV not found for search term '眼鏡', skipping...
# Pair CSV not found for search term '短褲', skipping...
# Pair CSV not found for search term '筆電支架', skipping...
# Pair CSV not found for search term '繪本', skipping...
# Pair CSV not found for search term '耳機', skipping...
# Pair CSV not found for search term '背包', skipping...
# Pair CSV not found for search term '背心', skipping...
# Pair CSV not found for search term '自拍棒', skipping...
# Pair CSV not found for search term '茶具', skipping...
# Pair CSV not found for search term '藍芽喇叭', skipping...
# Pair CSV not found for search term '蛙鏡', skipping...
# Pair CSV not found for search term '螢幕', skipping...
# Pair CSV not found for search term '行動電源', skipping...
# Pair CSV not found for search term '行李箱', skipping...
# Pair CSV not found for search term '衛生棉', skipping...
# Pair CSV not found for search term '襯衫', skipping...
# Pair CSV not found for search term '西裝褲', skipping...
# Pair CSV not found for search term '轉接線', skipping...
# Pair CSV not found for search term '運動鞋', skipping...
# Pair CSV not found for search term '開瓶器', skipping...
# Pair CSV not found for search term '防狼噴霧', skipping...
# Pair CSV not found for search term '電容', skipping...
# Pair CSV not found for search term '電阻', skipping...
# Pair CSV not found for search term '電風扇', skipping...
# Pair CSV not found for search term '食譜', skipping...
# Pair CSV not found for search term '馬克杯', skipping...
# Processing completed.
